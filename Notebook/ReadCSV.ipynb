# %%
import pandas as pd

# %%
frame = pd.read_csv("../files/texts.csv")

# %%
frame
# Out:
#        id                                              title  \
# 0       1       El acto solidario de la donación de órganos1
# 1       1       El acto solidario de la donación de órganos1
# 2       1       El acto solidario de la donación de órganos1
# 3       1       El acto solidario de la donación de órganos1
# 4       1       El acto solidario de la donación de órganos1
# 5       1       El acto solidario de la donación de órganos1
# 6       1       El acto solidario de la donación de órganos1
# 7       2          El valor de la televisión en la sociedad2
# 8       2          El valor de la televisión en la sociedad2
# 9       2          El valor de la televisión en la sociedad2
# 10      2          El valor de la televisión en la sociedad2
# 11      2          El valor de la televisión en la sociedad2
# 12      2          El valor de la televisión en la sociedad2
# 13      2          El valor de la televisión en la sociedad2
# ...

# %%
groupedFrame = frame.groupby('id')['value'].apply(lambda x: "%s" % ''.join(x))

# %%
groupedFrame[1]
# Out:
# 'Si bien los trasplantes se han convertido en una práctica habitual, aún persisten fuertes temores en la población para donar órganos, lograr su superación es la clave para aumentar el número de los donadores solidarios que hacen falta para salvar miles de vidas.Es preciso, entonces, que se aclaren algunas dudas para que las personas pierdan el miedo a donar. Primero, que lo complicado de los procedimientos de extirpación y trasplantación, en el que intervienen varios equipos médicos altamente especializados, vuelve muy difícil la existencia de mafias. Segundo, que la necesaria compatibilidad (afinidad de grupo sanguíneo) entre donante y receptor dificulta la posibilidad de muertes “a pedido”.La última cuestión es la más compleja; en la actualidad, aunque alguien haya manifestado expresamente su voluntad de donar, es a la familia a la que se consulta en el momento en que la donación puede efectuarse. Como se entiende, tal consulta llega en un momento difícil y poco propicio para las 
# ...
